# %%
responses = {
  "responses" : {
    "-Lz6nC_GBCNMOQ13a8yp" : {
      "cancelOrder" : "මම දැම්ම ඕඩර් එක මට කැන්සල් කරන්න ඕන",
      "changeAddress" : "මට දුන්න ඇඩ්‍රස් එක වෙනස් කරන්න ඕන",
      "name" : "Jeewanthi",
      "openingHousrs" : "විවෘත වෙලාව මොකක්ද",
      "order" : "කොල පාට එකේ සයිසස් මොනාද???",
      "telephone" : "දුරකථන අංකයක් දැනගැනීමට "
    },
    "-Lz6oOVZN4_QYyrzSYbf" : {
      "cancelOrder" : "ඇණවුම අවලංගු කිරීමට අවශ්‍යයි. මගේ ඇණවුම් අංකය #2345 .",
      "changeAddress" : "ඇණවුම සදහා ලබා දුන් ලිපිනය( Delivery Address) වෙනස් කරන්න අවශ්‍යයි.මගේ ඇණවුම් අංකය #2345",
      "name" : "තරිඳු ",
      "openingHousrs" : "ශාඛාව විවෘතව ඇති වේලාවන් දැන ගැනීමට අවශ්‍යයි.",
      "order" : "කොළ පාට t-shirt එකේ L size  එක තියනවා ද",
      "telephone" : "දුරකථන අංකය ලබා දෙන්න"
    },
    "-Lz6qjrChVK32I10Vusq" : {
      "cancelOrder" : "සමාවෙන්න!\nමට ඇණවුම අවලංගු කරන්න අවශ්‍යයි.\n#2345 ඇණවුම් අංකය",
      "changeAddress" : "#2345 ඇණවුම් අංකයට අදාල ලිපිනය මට වෙනස් කරන්න ඕනි. ",
      "name" : "Thejani",
      "openingHousrs" : "හිඟුරක්ගොඩ ශාඛාව විවෘත කරන වෙලාව කීයද?",
      "order" : "මේ කොල පාට ෂර්ට් එකේ ස්මෝල් සයිස් ඒවා තියෙනවද?",
      "telephone" : "හිඟුරක්ගොඩ ශාඛාවේ දුරකතන අංකය දැන ගන්න පුලුවන් වෙයිද මට ?"
    },
    "-Lz6qxTOlr_rFOTEizx8" : {
      "cancelOrder" : "මට #2345 ඇණවුම් අංකය තියෙන ඇණවුම අවලංගු කරලා දෙන්න",
      "changeAddress" : "මට #2345 ඇණවුම් අංකය යටතේ තියෙන Delivery address එක වෙනස් කරන්න ඕනෑ ",
      "name" : "Sakitha",
      "openingHousrs" : "මට බලංගොඩ පිහිටි SJ fashion ශාඛාව විවෘත කරලා තියෙන වේලාව දැන ගන්න ඕනෑ",
      "order" : "මට කොල පාට t-shirt එකේ mediun size එක තියෙනවා ද කියලා දැන ගන්න ඕනෑ",
      "telephone" : "මට බලංගොඩ පිහිටි SJ fashion ශාඛාවේ දුරකථන අංකය ලබා ගන්න පුලුවන් ද?"
    },
    "-Lz6r8wvj1JGk9Dj1XG0" : {
      "cancelOrder" : "මා දැමු ඇණවුමක් අවලංගු කිරිමට අවශ්‍යයි ",
      "changeAddress" : "#2345 මෙම ඇණවුම ට ලබා දුන් ඇණවුම බාර ගැනිමෙ ලිපිනය වෙනස් කිරිමට අවශ්‍යයි",
      "name" : "Dhammika ",
      "openingHousrs" : "කෑගල්ල නගර ශාඛාව විවෘත වේලාවන් දැන ගැනිමට හැකිද ?",
      "order" : "කොළ පැහැති t shirt එකෙ medium එක තිබෙද ?",
      "telephone" : "මට කෑගල්ල නගර ශාඛාවේ දුරකථන අංකය ලබා ගත හැකිද ?"
    },
    "-Lz6rMY-reOGd9_vKfE6" : {
      "cancelOrder" : "#2345 කැන්සල් කරන්න පුළුවන්ද ",
      "changeAddress" : "එඩ්‍රස් එක මාරු කරන්න පුළුවන්ද #2345",
      "name" : "Ruwan Dissanayaka ",
      "openingHousrs" : "අද shop එක ඇරලද ",
      "order" : "කොල පාට එකේ medium තියෙනවාද",
      "telephone" : "ලගම branch එකේ Phone number එක දෙන්න පුලුවන්ද "
    },
    "-Lz6rbGok0Hx8McaOQNs" : {
      "cancelOrder" : "මට #2345 order එක cancel කරන්න ඕන",
      "changeAddress" : "මට delivery address එක වෙනස් කරන්න පුළුවන් ද? Order #2345",
      "name" : "Savindi",
      "openingHousrs" : "ඔයාලා open කරන්නේ කීයටද?",
      "order" : "කොළ පාට එකෙන් small තියෙනවා ද?",
      "telephone" : "මට ඔයාලගේ කළුතර ශාඛාවේ නම්බර් එක දැන් ගන්න පුළුවන් ද?"
    },
    "-Lz6uEEzGszUmrELRxEz" : {
      "cancelOrder" : "කරුණාකර මේ Order එක Cancel කරන්න පුලුවන්ද?\nOrder Number එක #2345",
      "changeAddress" : "කරුණාකර මේ Order එකේ Address එක වෙනස් කරන්න පුලුවන්ද ?\n\nOrder Number එක #2345\nඅලුත් address එක අංක 23, මල්ලවපිටිය, නුවර පාර, කුරුණෑගල",
      "name" : "Thushara",
      "openingHousrs" : "opening - closing hours කොහොමද?",
      "order" : "කොළ පාට T-shirt එකේ Large Size එක තියනවාද ?",
      "telephone" : "කුරුණෑගල branch එකේ phone number එක ගන්න පුළුවන්ද ?"
    },
    "-Lz715BYugA31u1xMSv9" : {
      "cancelOrder" : "අනේ, #2345 ඔර්ඩර් එක කැන්සල්  කරන්න ඕනේ    ",
      "changeAddress" : "අනේ, #2345 ඔර්ඩර් එකේ ඩිලිවරි කරන්න තියන ඇඩ්‍රස් එක වැරදි. ඒක වෙනස් කරන්න ඕනේ    \n",
      "name" : "Upulee Pabasara",
      "openingHousrs" : "අනුරාධපුර ශෝ රූම් එක ඕපන් වෙලා තියෙන්නේ කීයේ ඉඳන් ද?",
      "order" : "මෙතන තියන කොළපාට ටී ශර්ට් එකේ ස්මෝල් සයිස් එක තියනවද ඔයාලා ගාව?",
      "telephone" : "අනුරාධපුර ශෝ රූම් එකට කතා කරන්න පුළුවන් නොම්බරයක් තියනවද? "
    },
    "-Lz72PUYjDKPAZQeD0Jd" : {
      "cancelOrder" : "#2345 ඇනවුම් අංකයෙන් තියන oder එක cancel කරන්න",
      "changeAddress" : "ඇනවුම් අංක#2345 සදහා ලබාදුන් ලිපිනය වෙනස් කරන්න ඕන",
      "name" : "Pasan Williams ",
      "openingHousrs" : "ශෝ රූම් එක කීයට වගේද open කරන්නේ",
      "order" : "කොල පාට එකෙන් large ගන්න තියේද",
      "telephone" : "මට ඕගොල්ලන්ගේ මාතර ශෝ රූම් තියන නම්බර් එකක් ගන්න ඕන"
    },
    "-Lz72U5SHtYcLARHMVib" : {
      "cancelOrder" : "මම කලින් කරපු ඇණවුමක් අවලංගු කරන්න පුළුවන් ද. අංකය 2345",
      "changeAddress" : "මම කලින් ඇණවුමක් කරා. ඒත් address එක වැරදියි. මට හරි address එකට වෙනස් කරගන්න පුළුවන් ද. Order number එක #2345",
      "name" : "Ruwan Sudheera",
      "openingHousrs" : "මට දැනගන්න පුළුවන් ද නුවර ශාකාව විවෘතව තියන වේලාවන්",
      "order" : "මේ කොලපාට t-shirt එකේ large size එකක් ගන්න පුලුවන් ද ",
      "telephone" : "සුභ උදෑසනක්, මට දැනගන්න පුළුවන් ද නුවර ශාකාවෙ දුරකථන අංකය"
    },
    "-Lz739ebyrksuUS0GeJR" : {
      "cancelOrder" : "මගේ ඇණවුම් අංකය #2345. මට මේ order එක cancel කරන්න ඕනා",
      "changeAddress" : " මගේ ඇණවුම් අංකය #2345. මට මේකේ දීපු address එක වෙනස් කර ගන්න ඕනා",
      "name" : "Yasiru ",
      "openingHousrs" : "ඒ ශාඛාවා ඇරලා තියෙන වෙලාවල් මොනවද? ",
      "order" : "කොළ පාට t shirt එකේ XL size එක තියෙනවද",
      "telephone" : "මට මතුගම ප්‍රදේශයේ තියෙන ඔයාලගෙ ශාඛාව සම්බන්ද කර ගන්න පුලුවන් දුරකතන අංකයක් දෙන්න"
    },
    "-Lz75eratmX90n-MwD7S" : {
      "cancelOrder" : "#2345 ඇණවුම් අංකයේ ඇණවුම අවලංගු කරන්න පුලුවන්ද?",
      "changeAddress" : "#2345 ඇණවුම් අංකයේ ලිපිනය වෙනස් කරන්න පුලුවන්ද?",
      "name" : "Maneesha",
      "openingHousrs" : "කෑගල්ල ශාඛාව විවෘතව ඇති වේලාවන් කියන්න",
      "order" : "කොල පාට එකේ S සයිස් එක තියනවද?",
      "telephone" : "මට කෑගල්ල ශාඛාවේ දුරකතන අංකය ලබා දෙන්න"
    },
    "-Lz79XhzA7oawwisgB4H" : {
      "cancelOrder" : "මගේ ඕඩර් එක කැන්සල් කරගන්න පුළුවන්ද",
      "changeAddress" : "මට මගේ ඇඩ්‍රස් එක වෙනස් කරගන්න ඕනා",
      "name" : "පවන්",
      "openingHousrs" : "කීයටද අරින්නෙ ඔයාලා",
      "order" : "කොල පාට එකේ සයිස් එක මොකක්ද",
      "telephone" : "මට දැනගන්න පුළුවන්ද මිනුවන්ගොඩ ශාඛාවේ දුරකතන අංකය"
    },
    "-Lz7AKsYctSsqqIg3Wdv" : {
      "cancelOrder" : "Mata #2345 ඇණවුම අවලංගු කිරීමට අවශ්‍යි",
      "changeAddress" : "මට  #2345 ඇණවුම සදහා ලබා දුන් ලිපිනය වෙනස් කිරීමට අවශ්‍යයි ",
      "name" : "Sahani Rajapakshe ",
      "openingHousrs" : "මට එය  විවෘතව ඇති වේලාවන් දැන ගැනීමට අවශ්‍යයි ",
      "order" : "කොළ පැහැ t-shirt එකෙහි L size තිබේද? ",
      "telephone" : "මට අනුරාධපුර නගරයේ තිබෙන SJ Fashion ශාඛාව හා සම්බන්ධ විය හැකි දුරකථන අංකයක් ලබා ගැනීමට අවශ්‍යයි "
    },
    "-Lz7CNV9j1tM0mxVHyIy" : {
      "cancelOrder" : "ඇණවුම අවලංගු කරන්න ",
      "changeAddress" : "ඇණවුම් අංකය #2345ට වෙනස් කරන්න",
      "name" : "Lakshika ",
      "openingHousrs" : "මට කොයි වෙලාවටද එන්න පුලුවන්?",
      "order" : "කොලපාට ෂර්ට් එකේ සයිස් නැද්ද?",
      "telephone" : "දුරකථන අංකය ලබා දෙන්න"
    },
    "-Lz7DuWcCrUxOh3vXZGD" : {
      "cancelOrder" : "මම ඔයාලට කලින් දීපු ඇණවුමක් දැන් කැන්සල් කරන්න පුළුවන් වෙයිද ? මගේ ඇණවුම් අංකය 2345",
      "changeAddress" : "මම ඔයාලගෙන් ටීෂර්ට් එකක් ගත්තා. මම කලින් දීපු ලිපිනය වෙනස් කරන්න පුළුවන්ද දැන්? මගේ ඇණවුම් අංකය 2345",
      "name" : "Mevuni",
      "openingHousrs" : "ඔයාලගෙ ශොප් එක කීයෙ ඉදන් කීය වෙනකං ද ඇරලා තියෙන්නෙ ?",
      "order" : "මට අවශ්‍ය කොළ පාට ටීෂර්ට් එකේ ස්මෝල් සයිස් එක. ඔයාලා ගාව දැනට ඒක තියනවද ?",
      "telephone" : "සුභ උදෑසනක්! මට ඔයාලගෙ කොට්ටාව  ශෝ රූම් එකේ ටෙලිෆෝන් නම්බර් එක දැනගන්න පුළුවන්ද ?"
    },
    "-Lz7F_vaZfsBahW3Zk9c" : {
      "cancelOrder" : "මට මගෙ ඕඩර් එක කැන්සල් කරන්න ඕන. ඕඩර් නම්බර් එක #2345",
      "changeAddress" : "මගෙ ඕඩර් එකේ ඩිලිවරි ඇඩ්‍රස් එක වෙනස් කර ගන්න ඕනි. ඕඩර් නම්බර් එක 2345",
      "name" : "Jithmi ",
      "openingHousrs" : "මට ඔයාලාගෙ මීගමුව ශාඛාව කීයෙ ඉඳං කීය වෙනකන්  ඇරලා තියෙනවද කියලා දැන ගන්න ඕන.",
      "order" : "හරි.  මේ කොළ පාට ටී එකේ මීඩියම් සයිස් තියෙනවද?",
      "telephone" : "මට ඔයාලාගෙ මීගමුව ශාඛාවෙ කන්ටැක්ට් නම්බර් එක දැන ගන්න ඕනි"
    },
    "-Lz7GUjc4U1X60RCUWrE" : {
      "cancelOrder" : "2345 ඇන්වුම අවලංගු කිරීමට අවශ්‍යයි ",
      "changeAddress" : "ලබා දුන් ලිපිනය වෙනස් කිරීමට අවශ්‍යයි ",
      "name" : "Madhushan",
      "openingHousrs" : "ශාඛාව විවෘත වන්නේ කීයටද",
      "order" : "කොල පැහැ tshirt එකේ small size තියනවද",
      "telephone" : "මට අවශ්‍යයි ලගම ශාඛාවේ දුරකථන අංකය"
    },
    "-Lz7JBmCBUFkS3e1gftK" : {
      "cancelOrder" : "මට මගේ order එක cancel කරන්න ඕන. නම්බර් එක #2345",
      "changeAddress" : "මගේ order number එක #2345. එකේ ලිපිනය වැරදි කරුණාකර ඒක වෙනස් කරගන්න පුලුවන්ද",
      "name" : "Lakshan",
      "openingHousrs" : "ඔයාල කීය වෙනකන් ඇරලද",
      "order" : "මට මේ කොල පාට ටී ශර්ට් එක තියනවද බලා ගන්න පුලුවන්ද",
      "telephone" : "මට මගේ ලගම තියෙන branch එකේ contact නම්බර් එක දෙන්න පුලුවන්ද"
    },
    "-Lz7JKFJVZmJm7VV89kX" : {
      "cancelOrder" : "මට මගේ ඇනවුම අවලංගු කිරීමට අවශ්‍යයි. මගේ ඇනවුම් අංකය වනුයේ #2345. ",
      "changeAddress" : "මගේ ඇනවුම් අංකය වනුයේ #2345. මට මෙකේ ලිපිනය වෙනස් කරන්න අවශ්‍යයි ",
      "name" : "Sandun Susantha ",
      "openingHousrs" : "මට දැනගැනීමට අවශ්‍යයි ඔබගේ ශාඛාව විවෘතව පවතින වෙලාවන් ",
      "order" : "මේ කොළ පාට එක කීයද ",
      "telephone" : "ඔබ කැමති නම් අපිට පුළුවන් ඔබගේ ප්‍රදේශයේ අපගේ ශාඛාවේ විස්තර ලබා දීමට. ඒ සඳහා ඔබගේ දුරකතන අංකය අවශ්‍ය වේ"
    },
    "-Lz7KmC4ifz9lqAYwxXU" : {
      "cancelOrder" : "Mata order aka cancel karanna puluwan da",
      "changeAddress" : "Mata delivery address aka wenas karanna onaaa",
      "name" : "Charith Madusanka",
      "openingHousrs" : "Koi welawata da arinne😂",
      "order" : "Kola pata akee medium size aka thiyenwada?",
      "telephone" : "Mata oyage number aka denwada??"
    },
    "-Lz7OklPpN-32ixITyO9" : {
      "cancelOrder" : "මම yelani. #2345 order එක මට cancel කරගන්න අවශ්‍යයි. ",
      "changeAddress" : "Delivery address එකක් දුන්නා මම. ඒත් ඒක දැන් මට වෙනස් කරන්න ඕනි. කෝමද කරගන්නේ ",
      "name" : "Yelani",
      "openingHousrs" : "Opening hours ගැන මට දැනගන්න පුළුවන්ද ",
      "order" : "කොළ පාට එක කීයක් වෙනවද ",
      "telephone" : "මම ගම්පහ ඉන්නේ. මට showroom එකක්‌ තියෙන තැනක් දැනගන්න ඕනි. "
    },
    "-Lz7Q1JOOGkOHtjtieja" : {
      "cancelOrder" : "මා හට #2344 ඇනවුම අවලංගු කිරීමට අවශ්‍යයි ",
      "changeAddress" : "මා හට #2345 ඇනවුම සදහා ලබාදුන් ලිපිනය වෙනස් කිරීමට අවශ්‍යයි ",
      "name" : "Niraji",
      "openingHousrs" : "මට ඔබලාගේ මාතර නගර ශාඛාව විවෘත කරන වෙලාව දැන ගන්න පුළුවන්ද ",
      "order" : "කොළ පැහැති tshirt එකේ XL ලබා ගතහැකිද",
      "telephone" : "මට ඔබලාගේ මාතර නගර ශාඛාවේ දුරකථන අංකය ලබා ගත හැකිද "
    },
    "-Lz7Qhv8q4B3czBNWFkF" : {
      "cancelOrder" : "කරැණාකරල #2345 ඕඩර් එක කැන්සල් කරන්න පුළුවන්ද?",
      "changeAddress" : "සුභ උදෑසනක්. මගෙ ඕඩර් අයි ඩී එක #2345. මට පුළුවන්ද මම දීල තියෙන ඩිලිවරි එඩ්‍රස් එක වෙනස් කරන්න?",
      "name" : "Jayani",
      "openingHousrs" : "මට දැනගන්න පුළුවන්ද කුරැණෑගල ශෝ රෑම් එක ඕපන් කරන්නෙ කීයටද කියල?",
      "order" : "මේ කොළ පාට ටී ෂර්ට් එකේ ස්මෝල් සයිස් එක තියනවද?",
      "telephone" : "සුභ උදෑසනක්. මට ඕගොල්ලන්ගෙ කුරැණෑගල ශෝ රෑම් එකේ ෆෝන් නම්බර් එකක් ගන්න පුළුවන්ද?"
    },
    "-Lz7UhqNb3rijUe6Jq73" : {
      "cancelOrder" : "කරුණාකර ඇණවුම  අවලංගු කරන්න. මගේ ඇණවුම් අංකය #2345",
      "changeAddress" : "ඇණවුම ලබා දුන් ලිපිනය වෙනස් කිරීමට අවශ්‍යයි. මගේ ඇණවුම් අංකය #2345",
      "name" : "බුද්ධි උපාධ්‍යා",
      "openingHousrs" : "ශාඛාව විවෘත කර තිබෙන වේලාවන්",
      "order" : "කොළ පාට t shirt එකේ small size තියේද",
      "telephone" : "මගේ නගරයේ ශාඛාව හා සම්බන්ධ විය හැකි දුරකථන අංකය ක් අවශ්‍යයි"
    },
    "-Lz7ZmIeYZ6fF5ed8yXl" : {
      "cancelOrder" : "#2345 ඇනවුම අවලංගු කිරීමට අවශ්‍යයි",
      "changeAddress" : "#2345 ඇනවුමේ ලිපිනය වෙනස් කරන්න අවශ්‍යයි",
      "name" : "Tharika sandeepani ",
      "openingHousrs" : "වැලිගම ශාඛාව විවෘත වේලාවන් මොනවාද ",
      "order" : "කොල පාට ටීෂර්ට් එකේ xs size තියෙනවද",
      "telephone" : "මට වැලිගම ශාඛාවේ දුරකථන අංකය ලබාගන්න ඕන "
    },
    "-Lz7soVJ7qzIZUNY99bT" : {
      "cancelOrder" : "2345 kiyama order eka cancel karanna oni",
      "changeAddress" : "2345 koyana order number eke address eka wenas karaganna oni",
      "name" : "ජනිත් ",
      "openingHousrs" : "Keeytada shop eka open karanne",
      "order" : "Me kola pata t eke xl nadda",
      "telephone" : "Mata dana ganna puluwanda colombo shakawe 4n number eka "
    },
    "-Lz7tn0mFAvzQIUQuvXP" : {
      "cancelOrder" : " #2345 order cancel",
      "changeAddress" : "#2345 address  change",
      "name" : "R.R",
      "openingHousrs" : "opening hors?",
      "order" : "Calvin and hobbes  eke large තියෙනවද",
      "telephone" : "දුරකතන අංකය ඕනෙ"
    },
    "-Lz9bRFmYgiG0S28N9pS" : {
      "cancelOrder" : "2345 ඇණවුම මට අවලංගු කරන්න පුලුවන්ද ",
      "changeAddress" : "2345 ඇණවුමේ ලිපිනය වෙනස් කරන්න පුලුවන්ද ",
      "name" : "San",
      "openingHousrs" : "ඒ ශාඛාව ඇරලා තියෙන්නෙ කීයේ ඉදලා කීය වෙනකන්ද",
      "order" : "කොල පාට ටී එකේ සයිසස් තියනවද",
      "telephone" : "මට අනුරාධපුර ශාඛාවේ දුරකතන අංකය දැනගන්න පුලුවන් ද?"
    },
    "-Lz9cylGzjo3fXz0jLbq" : {
      "cancelOrder" : "Mt me delivery ekacancel karaganna puluwanda",
      "changeAddress" : "Mt delivery adress eka wenas karanna one",
      "name" : "Losh",
      "openingHousrs" : "E branch eka mona welawal walada open karala tibenne ?",
      "order" : "Kola pata t shirt eke size L tyeda oyala gawa?",
      "telephone" : "Mt town eke tibena branch ekaka telephone no ekaka dana ganna one"
    },
    "-LzAIJd7PIoCqqhr9UrY" : {
      "cancelOrder" : "මට #2345 ඇණවුම අය්‍න් කරන්න ඔනෙ",
      "changeAddress" : "#2345 ඔඩර් එකෙ ලිපිනය මට වෙනස් කරන්න ඔනෙ.",
      "name" : "Dinesha",
      "openingHousrs" : "ඔයාගෙ කැලණිය ශාකව විවෘත වෙලා තියෙන්නේ කියෙ ඉදන් කියටද?",
      "order" : "මෙ කොල පාට එකෙ medium size එකක් තියෙනවද?",
      "telephone" : "මට කැලණිය අවට ශාකවක දුරකථන අංකයක් ගන්න පුළුවන්ද ?"
    },
    "-LzAP-1n2RueEJQZf2xM" : {
      "cancelOrder" : "මට මගේ ඇණවුම අවලංගු කරන්න ඕනේ.මගේ ඇණවුම් අංකය #2335",
      "changeAddress" : "මට මගේ ඇණවුම් ලිපිනය වෙනස් කරන්න ඕනේ. මගේ ඇනවුම් අංකය #2345. ",
      "name" : "janaka",
      "openingHousrs" : "මට කැලනිය ශාඛාව ඇරල තියෙන වෙලාව දැන ගන්න පුලුවන්ද?",
      "order" : "මට දැනගන්න පුලුවන්ද මෙතන කොල පාට t-shirt එකේ small සයිස් එක මට ගන්න පුලුවන්ද කියල? ",
      "telephone" : "මට ඕගොල්ලන්ගේ කැලනිය ශාඛාවේ දුරකතන අංකයක් එවන්න පුලුවන්ද?"
    },
    "-LzAP2vF4ewtM5RS1wxM" : {
      "cancelOrder" : "මට මගේ ඇණවුම අවලංගු කරන්න ඕනේ.මගේ ඇණවුම් අංකය #2335",
      "changeAddress" : "මට මගේ ඇණවුම් ලිපිනය වෙනස් කරන්න ඕනේ. මගේ ඇනවුම් අංකය #2345. ",
      "name" : "janaka",
      "openingHousrs" : "මට කැලනිය ශාඛාව ඇරල තියෙන වෙලාව දැන ගන්න පුලුවන්ද?",
      "order" : "මට දැනගන්න පුලුවන්ද මෙතන කොල පාට t-shirt එකේ small සයිස් එක මට ගන්න පුලුවන්ද කියල? ",
      "telephone" : "මට ඕගොල්ලන්ගේ කැලනිය ශාඛාවේ දුරකතන අංකයක් එවන්න පුලුවන්ද?"
    },
    "-LzAPDqL7aEtFGfWhnMg" : {
      "cancelOrder" : "මට මගේ ඇණවුම අවලංගු කරන්න ඕනේ. මගේ ඇණවුම් අංකය #2345",
      "changeAddress" : "මට මගේ delivery address එක වෙනස් කරන්න ඕනෙ..",
      "name" : "Dulanji",
      "openingHousrs" : "ඔයාලගෙ ශොප් එක කීය වෙනකම් ඇරල තියෙනවද?",
      "order" : "හරි.. මට මේ කොල පාට ටී ශර්ට් එකේ medium size එක ගන්න පුලුවන් ද?",
      "telephone" : "සුභ උදෑසනක්. මට ඔයාලගෙ කිරිබත්ගොඩ ශාඛාවේ දුරකතන අංකයක් ගන්න පුලුවන්ද?"
    },
    "-LzAPa1iB-oTVj2T-HlR" : {
      "cancelOrder" : "ඇණවුම් අංකය 2345 අවලංගු කරන්න ",
      "changeAddress" : "ඇණ්වුම් අංකය 2345 ලබා දුන් ලිපිනය වෙනස් කරන්න ",
      "name" : "Ruwan Bandara",
      "openingHousrs" : "ශාඛාව  විවෘත අති වෙලාව කුමක්ද",
      "order" : "කොල පාට ටි ශර්ට් එකෙ lage size තියෙනවද",
      "telephone" : "මට ගම්පහ නගරයෙ ශාඛාව හ සම්බන්ධ විය හැකි දුරකතන අංකයක් ලබා දෙන්න"
    },
    "-LzAVLvaoD-ytoOfSGkJ" : {
      "cancelOrder" : "මට අංක #2345 දරන ඇනවුම අවලංගු කිරීමට අවශ්‍ය යි.",
      "changeAddress" : "මට ඇනවුම සදහා ලබා දුන් ලිපිනය වෙනස් කිරීමට අවශ්‍ය යි.",
      "name" : "Sachini",
      "openingHousrs" : "මට කියන්න ශාඛාව විවෘතව ඇති වෙලාවන්.",
      "order" : "කොළ පාට එකෙන් size 10 තියෙනවද?",
      "telephone" : "සුබ උදෑසනක්. රත්නපුර නගරයේ ඇති ඔබගෙ ශාඛාවේ දුරකථන අංකය දැන ගන්න ඕනි."
    },
    "-LzAVo4sM2tI1xGjt9b8" : {
      "cancelOrder" : "mage order eka cancle kranna ona. Number eka 2345",
      "changeAddress" : "Mage address eka wenas karaganna ona. Number eka #2345",
      "name" : "Thisun",
      "openingHousrs" : "කවදාද එය open kranne. Welawa kiyada?",
      "order" : "Kola paata eke mage size ekata ganna pluwanda?",
      "telephone" : "Hi good morning. මට දැනගන්න ඕනා මගේ ප්‍රදේශයේ පිහිටා තිබෙන ශාකාවක දුරකතන අංකය"
    },
    "-LzAc_inhICyAEW6LIJL" : {
      "cancelOrder" : "මට මේක කැන්සල් කරන්න ඕනේ",
      "changeAddress" : "#2345 ඇනවුම සදහා මා ලබා දුන් ලිපිනය වෙනස් කල යුතුයි",
      "name" : "සහන්",
      "openingHousrs" : "විවෘත වේලාව",
      "order" : "කලු පාට එකෙ මීඩියම් එක තියනවද",
      "telephone" : "ගම්පහ කච්චේරිය"
    },
    "-LzAo7WAsjDGFtyUYvEv" : {
      "cancelOrder" : "How",
      "changeAddress" : "Kurunegala ",
      "name" : "Ayomi Dilhara Gunasekara",
      "openingHousrs" : "When is the open",
      "order" : "Green xxl",
      "telephone" : "Hi"
    },
    "-LzB-PDjBTtnjSVAYOIR" : {
      "cancelOrder" : "#2345 order එක cancel කරන්න.මං හදිස්සි වැඩකට එලියට යනව",
      "changeAddress" : "#2345 order එකේ address එක no.5,බුලට්ස් වීදිය,කොළඹ 7 විදිහට වෙනස් කරන්න ඕන",
      "name" : "සිසිත ජයවර්ධන ",
      "openingHousrs" : "කීයෙ ඉදන් කීය වෙනකන් showroom එක ඇරලද",
      "order" : "මේ කොල පාට එකේ M sze එක තියනවද",
      "telephone" : "Sj fashion එක සම්බන්ධ කරගන්න පුලුවන් number එකක් තියනවද"
    },
    "-LzB3D7gjkhKp39-tza7" : {
      "cancelOrder" : "#2345 ඇනවුම අවලංගු කරන්න\n",
      "changeAddress" : "#2345 ඇනවුමේ ලිපිනය මාරු කරන්න",
      "name" : "චානක ",
      "openingHousrs" : "නුවර  ශාකාව විවෘතව පවතීද",
      "order" : "කොල පාට් t-shirt එකේ xl තියෙනවද",
      "telephone" : "නුවර ශාකවේ දුරකතන අන්කය  කුමක්ද?"
    },
    "-LzBBtQEwVs4ip5DuADC" : {
      "cancelOrder" : " #2345 ඇණවුම අවලංගු කිරීමට අවශ්‍යයි ",
      "changeAddress" : "ඇණවුම සදහා ලබා දුන් ලිපිනය වෙනස් කිරීමට අවශ්‍යයි ",
      "name" : "Pubudu",
      "openingHousrs" : "ජා ඇල සම්පත් බැංකුව විවෘතව ඇති වේලාවන්",
      "order" : "XL Size එකෙන් තියෙනවද ",
      "telephone" : "ජා ඇල සම්පත් බැංකුවේ දුරකථන අංකය දැනගැනීමට අඅවශ්‍යයි "
    },
    "-LzBGwej7w8qTV3riWHO" : {
      "cancelOrder" : "මට ඇනවුම අවලංගු කරගන්න ඕන",
      "changeAddress" : "මට ඕන ඇනවුම කටුගස්තොටට ගෙන්වාගන්න",
      "name" : "Tharindu Bandara",
      "openingHousrs" : "මට දැනගන්න ඕන එම ආයතනය විවෘතව ඇති වේලාවන්",
      "order" : "මට ඕන මධයම ප්‍රමානයේ කමිසයක්",
      "telephone" : "මට දැනගන්න ඕන මහනුවර අබාන්ස් ආයතනයේ දුරකතන අංකය"
    },
    "-LzBXLg3DEUjO6A8YoM9" : {
      "cancelOrder" : "මට ඇණවුම අවලංගු කිරීමට අවශ්‍යයි, ඇනවුම් අංකය #2345",
      "changeAddress" : "ඇණවුම් අංකය #2345, සඳහා බෙදා හැරීමේ ලිපිනය වෙනස් කිරීමට අවශ්‍යය",
      "name" : "osura",
      "openingHousrs" : "28/5000\nඑම ශාඛාවේ ආරම්භක වේලාවන්?\n",
      "order" : "ඔබට කොළ පැහැති ටී ෂර්ට් එකෙන් L ප්‍රමාණය තිබේද?",
      "telephone" : "මොරටුව ශාඛාවේ දුරකථන අංකය ලබා ගැනීමට අවශ්‍යයි"
    },
    "-LzBluyQ7W076kNgijmV" : {
      "cancelOrder" : "Size එක මට ලොකුයි.මට ඇණවුම අවලංගු කරන්න ඔනේ",
      "changeAddress" : "මට ඇණවුම සදහා ලබා දුන් ලිපිනය වෙනස් කිරීමට අවශ්‍යයි.මෙ මගෙ ඇණවුම් අංකය #2345 ",
      "name" : "Anushi Weerasinghe",
      "openingHousrs" : "ශාඛාව විවෘතව ඇති වේලාවන් දැනගන්න ඔනේ.",
      "order" : "කොළ පැහැ t-shirt එකේ small size  එක ගන්න පුලුවන්ද?",
      "telephone" : "මට ඔගොල්ලන්ගෙ බොරලැස්ගමුව ශාඛාව හා සම්බන්ධ විය හැකි දුරකථන අංකයක් ලබා ගැනීමට අවශ්‍යයි"
    },
    "-LzBrRzNJyklb_86Mk6j" : {
      "cancelOrder" : "මට ඇණවුම අවලංගු කිරීමට අවශ්‍යයි.ඇණවුම් අංකය #2345 වේ",
      "changeAddress" : "ඇණවුම සදහා ලබා දුන් ලිපිනය වෙනස් කිරිමට අවශ්‍යයි.ඇණවුම් අංකය #2345 ",
      "name" : "Chamara",
      "openingHousrs" : "මට මහියංගන SJ  ශාඛාව විවෘතව ඇති වෙලාවන් දැනගැනිමට අවශ්‍යයි",
      "order" : "කොළ පැහැ t-shirt එකේ M සයිස් එක තියෙන්වද",
      "telephone" : "මට මහියංගන ශාඛාව හා සම්බන්ධ විය හැකි දුරකථන අංකයක් ලබා ගැනීමට අවශ්‍යයි"
    },
    "-LzC72M7WRIUAKlowmBx" : {
      "cancelOrder" : "#2345 ඕඩර් එක මට එපා",
      "changeAddress" : "මට කලින් දීපු ලිපිනය වෙනස් කරන්න ඕනි #2345 කියන ඕඩරේට",
      "name" : "Jeewantha",
      "openingHousrs" : "කැලණිය ශාඛාව විවෘතව තිබෙන වේලාවන් මොනවාද",
      "order" : "කොල පාට එකේ මීඩියම් සයිස් තියනවද",
      "telephone" : "මට ඕනි කැලණියෙ ශාඛාවෙ නම්බර් එකක්"
    },
    "-LzCHkQ0upCLTk1YFGgf" : {
      "cancelOrder" : "ඇනවුම වෙනස් කරන්න",
      "changeAddress" : "ඇනවුම වෙනස් කිරීමට අවශ්‍යයි",
      "name" : "Darshana ",
      "openingHousrs" : "විවෘතව ඇති වේලාවන් දැන ගැනීමට අවශ්‍යයි",
      "order" : "කොළ පැහැ t-shirt එකෙහි large  size ක තිබේද",
      "telephone" : "මට ගලගෙදර ශාඛාවේ දුරකථන අංකය අවශ්‍යයි"
    },
    "-LzCarO1rsPJ35SKDX7M" : {
      "cancelOrder" : "#2345 order එක cancel කරන්න",
      "changeAddress" : "#2345 order එක එවන address එක වෙනස් කරන්න ඕනේ",
      "name" : "Nisal",
      "openingHousrs" : "මට පානදුර ශාඛාව ඇරලා තියෙන වෙලාව කියන්න",
      "order" : "කොළ පාට shirt එකේ medium size තියෙනවද?",
      "telephone" : "මට පානදුර ශාඛාවේ දුරකථන අංකය එවන්න"
    },
    "-LzCbyfks3m8-Dv3E62D" : {
      "cancelOrder" : "යම් හෙතුවක් නිසා  මගෙ ඇනවුම අවලංගු කරන්න ඔනෙ මගෙ ඇනවුම් අංකය 2345",
      "changeAddress" : "මට මගෙ ඇනවුමට ලබා දුන්න ලිපිනය වෙනස් කරන්න ඔනෙ මගෙ ඇනවුම් අංකය 2345 ",
      "name" : "akila",
      "openingHousrs" : "ඔයාලගෙ ගම්පහ ශාකාව විවෘත ඇත්තෙ කොයි වෙලාවන් වලද",
      "order" : "කොල පාට ටි ශර්ට් එකෙ මිඩියම් සයිස් තියෙනවද",
      "telephone" : "මට ඔයාලගෙ ගම්පහ ශාකාවෙ දුරකතන අංකය ලබා ගන්න පුලුවන්ද"
    },
    "-LzCfRiLVoG9_3Bv0HRG" : {
      "cancelOrder" : "මට #2345 ඕර්ඩර් එක කැනසල් කරන්න ඕන",
      "changeAddress" : "මට #2345 ඇඩ්රස් එක වෙනස් කරන්න ඕන",
      "name" : "Madusha Lakmini",
      "openingHousrs" : "ඒක මොන ටයිම් එකේද ඇරලා තියෙන්නේ?",
      "order" : "ඔය කොළ පාට ටී එකේ ගාන කොහොමද? ",
      "telephone" : "ගුඩ් මෝර්නින්ග්! මට දැනගන්න පුළුවන්ද ඔයාලගේ මාතලේ බ්‍රාන්ච් එකේ ෆෝන් නම්බර් එක? "
    },
    "-LzCgpt8I-0pTSROZCAc" : {
      "cancelOrder" : "Cancel my order",
      "changeAddress" : "Change the delivery address",
      "name" : "KK",
      "openingHousrs" : "When ll you open shop?",
      "order" : "I don't want",
      "telephone" : "Hello burba"
    },
    "-LzDGEJY3PClbm3ebKBl" : {
      "cancelOrder" : "ඇණවුම් අංකය #2345 මට මේ order එක cancel කරන්න ඕනි",
      "changeAddress" : "ඇණවුම් අංකය #2345 ට දුන්න delivery address එක වෙනස් කරන්නෙ කොහොමද?",
      "name" : "දිනෙත් ශාන් ගිම්හාන",
      "openingHousrs" : "මට දැන ගන්න පුලුවන්ද පානදුර ශාඛාව ඇරලා තියෙන්නෙ කීයේ ඉදන් කීය වෙනකම්ද කියලා",
      "order" : "කොල පාට ටී ශර්ට් එකේ large size එක තියෙනවද?",
      "telephone" : "මට දැන ගන්න පුලුවන්ද ඔයගොල්ලන්ගේ පානදුර ශාඛාවේ දුරකතන අංකය?"
    },
    "-LzDGYlU1oglZ8Be3NoJ" : {
      "cancelOrder" : "ඇණවුම් අංකය #2345 මට මේ order එක cancel කරන්න ඕනි",
      "changeAddress" : "ඇණවුම් අංකය #2345 ට දුන්න delivery address එක වෙනස් කරන්නෙ කොහොමද?",
      "name" : "දිනෙත් ශාන් ගිම්හාන",
      "openingHousrs" : "මට දැන ගන්න පුලුවන්ද පානදුර ශාඛාව ඇරලා තියෙන්නෙ කීයේ ඉදන් කීය වෙනකම්ද කියලා",
      "order" : "කොල පාට ටී ශර්ට් එකේ large size එක තියෙනවද?",
      "telephone" : "මට දැන ගන්න පුලුවන්ද ඔයගොල්ලන්ගේ පානදුර ශාඛාවේ දුරකතන අංකය?"
    },
    "-LzDMeKxFzBSDMMEn9jD" : {
      "cancelOrder" : "Please can you cancel the order ",
      "changeAddress" : "I need Chang the dilivery",
      "name" : "Sachini ",
      "openingHousrs" : "What time do you open shop",
      "order" : "2 nd one",
      "telephone" : "Can you send me your contact number "
    },
    "-LzE7ZY1pXC3iLrPlqmZ" : {
      "cancelOrder" : "ඇණවුම් අංකය #2345 අදාල ඇණවුම අවලංගු කරන්න ඕනෙ",
      "changeAddress" : "ඇණවුම් අංකය #2345 අදාල ලිපිනය වෙනස් කරන්න ඕනෙ",
      "name" : "සනූජා",
      "openingHousrs" : "කුරුණෑගල ශාඛාව විවෘත වේලාවන් මොනවාද?",
      "order" : " කොළ පැහැ t-shirt එකෙ small size එක කියනවද?",
      "telephone" : "සුභ උදෑසනක්! කුරුණෑගල ශාඛාවෙ  දුරකථන අංකය ගන්න පුලුවන්ද"
    },
    "-LzFSOOr0CjkXU4eQlVT" : {
      "cancelOrder" : "#2345 ඇණවුම අවලංගු කරන්න ",
      "changeAddress" : "#2345 ඇණවුමේ ලිපිනය වෙනස් කළ යුතුයි ",
      "name" : "Yasiru ",
      "openingHousrs" : "කීයටද  ශාඛාව විවෘතව තිබෙන්නේ ",
      "order" : "කොළ පාට tshirt  එකේ small size එක තිබෙනවා ද",
      "telephone" : "මට නුවරඑළිය ශාඛාවේ දුරකථන අංකය අවශ්‍යයි ."
    }
  }
}

# %%
print(responses['responses']['-Lz6nC_GBCNMOQ13a8yp'])
# Out:
# {'cancelOrder': 'මම දැම්ම ඕඩර් එක මට කැන්සල් කරන්න ඕන', 'changeAddress': 'මට දුන්න ඇඩ්\u200dරස් එක වෙනස් කරන්න ඕන', 'name': 'Jeewanthi', 'openingHousrs': 'විවෘත වෙලාව මොකක්ද', 'order': 'කොල පාට එකේ සයිසස් මොනාද???', 'telephone': 'දුරකථන අංකයක් දැනගැනීමට '}

# %%
### get columns
#columns = ["name","cancelOrder","changeAddress","openingHousrs","order","telephone"]
columns = ["name","text","class"]

# %%
values = []

## add header
values.append(columns)

for key in responses['responses']:
  values.append([responses['responses'][key]['name'],responses['responses'][key]["cancelOrder"],"cancelOrder"])
  values.append([responses['responses'][key]['name'],responses['responses'][key]["changeAddress"],"changeAddress"])
  values.append([responses['responses'][key]['name'],responses['responses'][key]["openingHousrs"],"openingHousrs"])
  values.append([responses['responses'][key]['name'],responses['responses'][key]["order"],"askSizes"])
  values.append([responses['responses'][key]['name'],responses['responses'][key]["telephone"],"telephone"])

# %%
import pandas as pd 
pd.DataFrame(values).to_csv("/file.csv", header=None, index=None)

# %%
df = pd.read_csv('/file.csv')

# %%
df.head(15)
# Out:
#          name                                               text          class
# 0   Jeewanthi               මම දැම්ම ඕඩර් එක මට කැන්සල් කරන්න ඕන    cancelOrder
# 1   Jeewanthi                 මට දුන්න ඇඩ්‍රස් එක වෙනස් කරන්න ඕන  changeAddress
# 2   Jeewanthi                                 විවෘත වෙලාව මොකක්ද  openingHousrs
# 3   Jeewanthi                        කොල පාට එකේ සයිසස් මොනාද???       askSizes
# 4   Jeewanthi                           දුරකථන අංකයක් දැනගැනීමට       telephone
# 5      තරිඳු   ඇණවුම අවලංගු කිරීමට අවශ්‍යයි. මගේ ඇණවුම් අංකය ...    cancelOrder
# 6      තරිඳු   ඇණවුම සදහා ලබා දුන් ලිපිනය( Delivery Address) ...  changeAddress
# 7      තරිඳු       ශාඛාව විවෘතව ඇති වේලාවන් දැන ගැනීමට අවශ්‍යයි.  openingHousrs
# 8      තරිඳු             කොළ පාට t-shirt එකේ L size  එක තියනවා ද       askSizes
# 9      තරිඳු                               දුරකථන අංකය ලබා දෙන්න      telephone
# 10    Thejani  සමාවෙන්න!\nමට ඇණවුම අවලංගු කරන්න අවශ්‍යයි.\n#2...    cancelOrder
# ...

# %%
df.shape
# Out:
# (58, 6)

# %%
df['name']
